# %%
import json

import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, label_ranking_average_precision_score, dcg_score

from fos.settings import ASSETS_DIR

meta = pd.read_pickle(ASSETS_DIR / "fields/fos.pkl.gz")
meta.index = meta.index.astype(int)

true = pd.read_json("autumn_cs_annotations.jsonl", lines=True)
true.set_index("merged_id", inplace=True)
true.head()
# Out:
#                                                                  title  \
# merged_id
# carticle_0165770296  Networked measurement and control system based...
# carticle_0065264564  Hybrid Cloud Rendering System for Massive CAD ...
# carticle_0085809617  To Shorten Total Trip Time for Passengers by R...
# carticle_0188819773   Connectivity of Wireless Sensor Complex Networks
# carticle_0021247370  Proceedings of the Second International Worksh...
#
#                                                               abstract  \
# merged_id
# carticle_0165770296  The application of networked measurement and c...
# carticle_0065264564  The recent advances in cloud services enable a...
# carticle_0085809617
# carticle_0188819773
# carticle_0021247370
#
#                                                                   text  \
# merged_id
# carticle_0165770296  networked measurement and control system based...
# carticle_0065264564  hybrid cloud rendering system for massive cad ...
# carticle_0085809617  to shorten total trip time for passengers by r...
# carticle_0188819773   connectivity of wireless sensor complex networks
# carticle_0021247370  proceedings of the second international worksh...
#
#                                                                options  \
# merged_id
# carticle_0165770296  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0065264564  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0085809617  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0188819773  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0021247370  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
#
#                                                      meta  \
# merged_id
# carticle_0165770296  {'merged_id': 'carticle_0165770296'}
# carticle_0065264564  {'merged_id': 'carticle_0065264564'}
# carticle_0085809617  {'merged_id': 'carticle_0085809617'}
# carticle_0188819773  {'merged_id': 'carticle_0188819773'}
# carticle_0021247370  {'merged_id': 'carticle_0021247370'}
#
#                                                                   html  \
# merged_id
# carticle_0165770296  Networked measurement and control system based...
# carticle_0065264564  Hybrid Cloud Rendering System for Massive CAD ...
# carticle_0085809617  To Shorten Total Trip Time for Passengers by R...
# carticle_0188819773   Connectivity of Wireless Sensor Complex Networks
# carticle_0021247370  Proceedings of the Second International Worksh...
#
#                      _input_hash  _task_hash _view_id  \
# merged_id
# carticle_0165770296   -943446144   529049400   blocks
# carticle_0065264564   -180950055  1850390516   blocks
# carticle_0085809617    410318024  1731964067   blocks
# carticle_0188819773   1677727149  1084729738   blocks
# carticle_0021247370    224564397  1929177218   blocks
#
#                                           accept  \
# merged_id
# carticle_0165770296                   [Networks]
# carticle_0065264564  [High Performace Computing]
# carticle_0085809617                      [AI/ML]
# carticle_0188819773                   [Networks]
# carticle_0021247370  [IR & Knowledge management]
#
#                                            config  answer  _timestamp
# merged_id
# carticle_0165770296  {'choice_style': 'multiple'}  accept  1647991522
# carticle_0065264564  {'choice_style': 'multiple'}  accept  1647991549
# carticle_0085809617  {'choice_style': 'multiple'}  accept  1647991567
# carticle_0188819773  {'choice_style': 'multiple'}  accept  1647991571
# carticle_0021247370  {'choice_style': 'multiple'}  accept  1647991622

# %%
true['answer'].value_counts()
# Out:
# accept    220
# reject     31
# ignore      2
# Name: answer, dtype: int64

# %%
true = true.query("answer == 'accept'").copy()

# %%
labels = [x['id'] for x in true.iloc[0]['options']]
labels
# Out:
# ['Algorithms',
#  'AI/ML',
#  'Computer engineering',
#  'Graphics',
#  'Networks',
#  'Security & Privacy',
#  'IR & Knowledge management',
#  'Software',
#  'Theoretical computer science',
#  'High Performace Computing',
#  'Human–computer interaction']

# %%
y_true = {}
for merged_id, row in true.iterrows():
    y_true[merged_id] = {label: label in row['accept'] for label in labels}

# %%
from fos.model import FieldModel

field_model = FieldModel("en")

# %%
from fos.util import preprocess_text
true['text'] = true.apply(preprocess_text, axis=1)
true['scores'] = true['text'].\
    apply(field_model.embed).\
    apply(field_model.score).\
    apply(lambda x: x.average())
true.head()
# Out:
#                                                                  title  \
# merged_id
# carticle_0165770296  Networked measurement and control system based...
# carticle_0065264564  Hybrid Cloud Rendering System for Massive CAD ...
# carticle_0085809617  To Shorten Total Trip Time for Passengers by R...
# carticle_0188819773   Connectivity of Wireless Sensor Complex Networks
# carticle_0021247370  Proceedings of the Second International Worksh...
#
#                                                               abstract  \
# merged_id
# carticle_0165770296  The application of networked measurement and c...
# carticle_0065264564  The recent advances in cloud services enable a...
# carticle_0085809617
# carticle_0188819773
# carticle_0021247370
#
#                                                                   text  \
# merged_id
# carticle_0165770296  networked measurement and control system based...
# carticle_0065264564  hybrid cloud rendering system for massive cad ...
# carticle_0085809617  to shorten total trip time for passengers by r...
# carticle_0188819773   connectivity of wireless sensor complex networks
# carticle_0021247370  proceedings of the second international worksh...
#
#                                                                options  \
# merged_id
# carticle_0165770296  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0065264564  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0085809617  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0188819773  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0021247370  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
#
#                                                      meta  \
# merged_id
# carticle_0165770296  {'merged_id': 'carticle_0165770296'}
# carticle_0065264564  {'merged_id': 'carticle_0065264564'}
# carticle_0085809617  {'merged_id': 'carticle_0085809617'}
# carticle_0188819773  {'merged_id': 'carticle_0188819773'}
# carticle_0021247370  {'merged_id': 'carticle_0021247370'}
#
#                                                                   html  \
# merged_id
# carticle_0165770296  Networked measurement and control system based...
# carticle_0065264564  Hybrid Cloud Rendering System for Massive CAD ...
# carticle_0085809617  To Shorten Total Trip Time for Passengers by R...
# carticle_0188819773   Connectivity of Wireless Sensor Complex Networks
# carticle_0021247370  Proceedings of the Second International Worksh...
#
#                      _input_hash  _task_hash _view_id  \
# merged_id
# carticle_0165770296   -943446144   529049400   blocks
# carticle_0065264564   -180950055  1850390516   blocks
# carticle_0085809617    410318024  1731964067   blocks
# carticle_0188819773   1677727149  1084729738   blocks
# carticle_0021247370    224564397  1929177218   blocks
#
#                                           accept  \
# merged_id
# carticle_0165770296                   [Networks]
# carticle_0065264564  [High Performace Computing]
# carticle_0085809617                      [AI/ML]
# carticle_0188819773                   [Networks]
# carticle_0021247370  [IR & Knowledge management]
#
#                                            config  answer  _timestamp  \
# merged_id
# carticle_0165770296  {'choice_style': 'multiple'}  accept  1647991522
# carticle_0065264564  {'choice_style': 'multiple'}  accept  1647991549
# carticle_0085809617  {'choice_style': 'multiple'}  accept  1647991567
# carticle_0188819773  {'choice_style': 'multiple'}  accept  1647991571
# carticle_0021247370  {'choice_style': 'multiple'}  accept  1647991622
#
#                                                                 scores
# merged_id
# carticle_0165770296  [0.6252872995068798, 0.6508370191531042, 0.624...
# carticle_0065264564  [0.6416180819090423, 0.6759123919423775, 0.652...
# carticle_0085809617  [0.6006255887318293, 0.6235317604846059, 0.616...
# carticle_0188819773  [0.2208237385978619, 0.2508910754504358, 0.224...
# carticle_0021247370  [0.2863368251756025, 0.3098823845821171, 0.274...

# %%
true['field_scores'] = true['scores'].apply(
    lambda x: {
        meta.loc[int(field_id), 'display_name']: score
        for field_id, score in zip(field_model.index, x)
    })
true.head()
# Out:
#                                                                  title  \
# merged_id
# carticle_0165770296  Networked measurement and control system based...
# carticle_0065264564  Hybrid Cloud Rendering System for Massive CAD ...
# carticle_0085809617  To Shorten Total Trip Time for Passengers by R...
# carticle_0188819773   Connectivity of Wireless Sensor Complex Networks
# carticle_0021247370  Proceedings of the Second International Worksh...
#
#                                                               abstract  \
# merged_id
# carticle_0165770296  The application of networked measurement and c...
# carticle_0065264564  The recent advances in cloud services enable a...
# carticle_0085809617
# carticle_0188819773
# carticle_0021247370
#
#                                                                   text  \
# merged_id
# carticle_0165770296  networked measurement and control system based...
# carticle_0065264564  hybrid cloud rendering system for massive cad ...
# carticle_0085809617  to shorten total trip time for passengers by r...
# carticle_0188819773   connectivity of wireless sensor complex networks
# carticle_0021247370  proceedings of the second international worksh...
#
#                                                                options  \
# merged_id
# carticle_0165770296  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0065264564  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0085809617  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0188819773  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
# carticle_0021247370  [{'id': 'Algorithms', 'text': 'Algorithms'}, {...
#
#                                                      meta  \
# merged_id
# carticle_0165770296  {'merged_id': 'carticle_0165770296'}
# carticle_0065264564  {'merged_id': 'carticle_0065264564'}
# carticle_0085809617  {'merged_id': 'carticle_0085809617'}
# carticle_0188819773  {'merged_id': 'carticle_0188819773'}
# carticle_0021247370  {'merged_id': 'carticle_0021247370'}
#
#                                                                   html  \
# merged_id
# carticle_0165770296  Networked measurement and control system based...
# carticle_0065264564  Hybrid Cloud Rendering System for Massive CAD ...
# carticle_0085809617  To Shorten Total Trip Time for Passengers by R...
# carticle_0188819773   Connectivity of Wireless Sensor Complex Networks
# carticle_0021247370  Proceedings of the Second International Worksh...
#
#                      _input_hash  _task_hash _view_id  \
# merged_id
# carticle_0165770296   -943446144   529049400   blocks
# carticle_0065264564   -180950055  1850390516   blocks
# carticle_0085809617    410318024  1731964067   blocks
# carticle_0188819773   1677727149  1084729738   blocks
# carticle_0021247370    224564397  1929177218   blocks
#
#                                           accept  \
# merged_id
# carticle_0165770296                   [Networks]
# carticle_0065264564  [High Performace Computing]
# carticle_0085809617                      [AI/ML]
# carticle_0188819773                   [Networks]
# carticle_0021247370  [IR & Knowledge management]
#
#                                            config  answer  _timestamp  \
# merged_id
# carticle_0165770296  {'choice_style': 'multiple'}  accept  1647991522
# carticle_0065264564  {'choice_style': 'multiple'}  accept  1647991549
# carticle_0085809617  {'choice_style': 'multiple'}  accept  1647991567
# carticle_0188819773  {'choice_style': 'multiple'}  accept  1647991571
# carticle_0021247370  {'choice_style': 'multiple'}  accept  1647991622
#
#                                                                 scores  \
# merged_id
# carticle_0165770296  [0.6252872995068798, 0.6508370191531042, 0.624...
# carticle_0065264564  [0.6416180819090423, 0.6759123919423775, 0.652...
# carticle_0085809617  [0.6006255887318293, 0.6235317604846059, 0.616...
# carticle_0188819773  [0.2208237385978619, 0.2508910754504358, 0.224...
# carticle_0021247370  [0.2863368251756025, 0.3098823845821171, 0.274...
#
#                                                           field_scores
# merged_id
# carticle_0165770296  {'Industrial organization': 0.6252872995068798...
# carticle_0065264564  {'Industrial organization': 0.6416180819090423...
# carticle_0085809617  {'Industrial organization': 0.6006255887318293...
# carticle_0188819773  {'Industrial organization': 0.2208237385978619...
# carticle_0021247370  {'Industrial organization': 0.2863368251756025...

# %%
cs_fields = """\
Library science
Algorithm
Pattern recognition
Computer vision
Computer network
Knowledge management
World Wide Web
Data science
Human–computer interaction
Data mining
Software engineering
Computer security
Real-time computing
Information retrieval
Machine learning
Distributed computing
Multimedia
Internet privacy
Computer hardware
Natural language processing
Theoretical computer science
Telecommunications
Programming language
Simulation
Speech recognition
Embedded system
Operating system
Artificial intelligence
Computer graphics (images)
Database
Parallel computing
Computer engineering
Computational science
Computer architecture""".split('\n')
cs_fields
# Out:
# ['Library science',
#  'Algorithm',
#  'Pattern recognition',
#  'Computer vision',
#  'Computer network',
#  'Knowledge management',
#  'World Wide Web',
#  'Data science',
#  'Human–computer interaction',
#  'Data mining',
#  'Software engineering',
#  'Computer security',
#  'Real-time computing',
#  'Information retrieval',
#  'Machine learning',
#  'Distributed computing',
#  'Multimedia',
#  'Internet privacy',
#  'Computer hardware',
#  'Natural language processing',
#  'Theoretical computer science',
#  'Telecommunications',
#  'Programming language',
#  'Simulation',
#  'Speech recognition',
#  'Embedded system',
#  'Operating system',
#  'Artificial intelligence',
#  'Computer graphics (images)',
#  'Database',
#  'Parallel computing',
#  'Computer engineering',
#  'Computational science',
#  'Computer architecture']

# %%
true['field_scores'] = true['field_scores'].\
    apply(lambda x: {k: v for k, v in x.items() if k in cs_fields})

# %%
true['field_scores'] = true['field_scores'].\
    apply(lambda x: sorted(x.items(), key=lambda x: x[1], reverse=True))

# %%
true['top_pred'] = true['field_scores'].apply(lambda x: x[0][0])
true['top_pred']
# Out:
# merged_id
# carticle_0165770296              Computer network
# carticle_0065264564    Computer graphics (images)
# carticle_0085809617                     Algorithm
# carticle_0188819773              Computer network
# carticle_0021247370                  Data science
#                                   ...
# carticle_0171028584               Embedded system
# carticle_0023217678    Human–computer interaction
# carticle_0163850398              Operating system
# carticle_0000293880              Computer network
# carticle_0189168626    Human–computer interaction
# Name: top_pred, Length: 220, dtype: object

# %%
agg = {
    "AI/ML": "Artificial intelligence	Data mining	Pattern recognition	Machine learning	Data science".split('\t'),
    "Computer engineering": "Computer engineering	Computer architecture	Computer hardware".split('\t'),
    "Networks": "Computer network	World Wide Web".split('\t'),
    'IR & Knowledge management': "Knowledge management	Database	Information retrieval	Library science".split('\t'),
    'Software': "Software engineering	Programming language	Operating system	Embedded system".split('\t'),
    'Security & Privacy': "Computer security	Internet privacy".split('\t'),
    'High Performace Computing': "Real-time computing	Distributed computing	Parallel computing".split('\t'),
}
y_top_pred = {}
for i, row in true.iterrows():
    y_top_pred[i] = row['top_pred']
    for cat, subcats in agg.items():
        if row['top_pred'] in subcats:
            y_top_pred[i] = cat
            break

y_pred = {}
for i, row['field_scores'] in true.iterrows():

    result =
    for cat, subcats in agg.items():

    row['field_scores']
    break

row['field_scores']

# y_pred = {}
# for i, row in true.iterrows():
# Out:
# [('Computer network', 0.7003316057060335),
#  ('Distributed computing', 0.6647598722399581),
#  ('Operating system', 0.6645782615319036),
#  ('Embedded system', 0.6608830854579071),
#  ('Simulation', 0.6608791964571538),
#  ('Telecommunications', 0.6559305557162505),
#  ('Computer security', 0.6539448830040847),
#  ('Theoretical computer science', 0.6526612826182231),
#  ('Computer architecture', 0.6518544687688257),
#  ('Computational science', 0.6508370191531042),
#  ('Real-time computing', 0.647983174449315),
#  ('Computer vision', 0.6479559182596587),
#  ('Computer engineering', 0.6460526312980773),
#  ('Parallel computing', 0.6441418055653203),
#  ('Database', 0.6437524455930167),
#  ('Multimedia', 0.6430017792477815),
#  ('Human–computer interaction', 0.6418413537056039),
#  ('Speech recognition', 0.6408775341946321),
#  ('Machine learning', 0.6392496141537373),
#  ('Computer graphics (images)', 0.6390952197815649),
#  ('Information retrieval', 0.638900683007743),
#  ('Computer hardware', 0.6370022895252111),
#  ('Artificial intelligence', 0.6360089567864561),
#  ('Software engineering', 0.6354407285882796),
#  ('Pattern recognition', 0.6343907283314522),
#  ('Natural language processing', 0.633497102388125),
#  ('Knowledge management', 0.6331822147742932),
#  ('Data mining', 0.6323789441453518),
#  ('Data science', 0.6316627177946229),
#  ('World Wide Web', 0.6315631413653283),
#  ('Algorithm', 0.6315629229248207),
#  ('Internet privacy', 0.6293238754985894),
#  ('Programming language', 0.626964210587038),
#  ('Library science', 0.624400559822179)]

# %%
y_true = dict(sorted(y_true.items()))
y_pred = dict(sorted(y_top_pred.items()))

# %%
def true_to_array(true):
    arrays = []
    for row in true.values():
        sorted_row = dict(sorted(row.items()))
        arrays.append(np.array(list(sorted_row.values())).astype(int))
    return np.array(arrays)

def top_k_accuracy(true_values, pred_values, top_k=5, proportion=True):
    true_values = list(true_values.values())
    pred_values = list(pred_values.values())
    assert len(true_values) == len(pred_values)
    n = 0
    correct = {i: 0 for i in range(top_k)}
    for true, pred in zip(true_values, pred_values):
        true_fields = {k for k, v in true.items() if v}
        if not len(true_fields):
            # If we've restricted the labels for evalutaion to STEM fields, discard the docs with no positive labels
            continue
        # Ensure that fields are in order of score descending
        pred = [k for k, v in sorted(pred.items(), key=lambda x: x[1], reverse=True)]
        # This is a hack for having annotated multilabel -- if there are 2 true labels, we're taking them
        # interchangeably. We look at the top-scoring label, and check whether it's among the true labels. If so, we
        # count that as accurate @ 1. If not, we check the 2nd-scoring label. If among the true labels, that's accurate
        # @ 2
        for i in range(top_k):
            if pred[i] in true_fields:
                correct[i] += 1
                break
        n += 1
    # The above gave us counts for how often the top-scoring field is correct; if not, how often the 2nd-ranked field
    # label is correct ... and so on to the 5th-ranked field. Taking a cumulative sum over these counts gives us how
    # often a correct label (*the* true label if we manually chose a single label, or one of the correct labels if we
    # chose more than one ... in practice it's mostly 1 label; some 2 labels; rarely 3 labels) is the top label; among
    # the top 2 labels; among the top 3 labels ...
    for i in reversed(range(top_k)):
        for j in range(i):
            correct[i] += correct[j]

    if proportion:
        return {k: x / n for k, x in correct.items()}
    return correct

def to_arrays(doc_scores):
    # Structure scores for sklearn.metrics
    arrays = []
    for doc_id, scores in doc_scores.items():
        arrays.append([v for k, v in sorted(scores.items())])
    return arrays

def pred_to_array(pred, ranks=False):
    arrays = []
    for row in pred.values():
        sorted_row = dict(sorted(row.items()))
        row_array = np.array(list(sorted_row.values()))
        if ranks:
            arrays.append(np.array(list(reversed(row_array.argsort()))) + 1)
        else:
            arrays.append(row_array)
    return np.array(arrays)

def dichotomize(scores, top_k=1):
    """Dichotomize an array of continuous field scores such that the top_k fields are true and the rest false."""
    output = {}
    ordered_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    for i, (label, score) in enumerate(ordered_scores, 1):
        output[label] = i <= top_k
    return output

# %%
# top_k_accuracy(y_true, y_pred)
y_true
# Out:
# {'carticle_0000255204': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0000293880': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': True,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0001990826': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0002436541': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0002565774': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': True,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0003044952': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0004118963': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0004834905': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': True,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0006211110': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0007064058': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0009278952': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0009850090': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0011291905': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0012543572': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0013350185': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': True},
#  'carticle_0013603907': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0014121826': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0017394439': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0017641391': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0018137783': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0018187318': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0019307725': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0020037141': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0021247370': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0022843745': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0023217678': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0024107731': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0024168805': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0024385204': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0024558825': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': True,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0026094802': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0028126695': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': True,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0028991759': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0029314895': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0030106975': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0030404407': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0031233239': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0033899195': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0036075099': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0036618532': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0036801392': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0041076223': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0043853873': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0046488495': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0047104493': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0050796348': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0051872470': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0052558902': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': True,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0052682019': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0053700591': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0053742823': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0055755770': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0055761849': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': True,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0056197364': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': True},
#  'carticle_0056775235': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0056828099': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': True,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0058086075': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0058952208': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0060114497': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0060565286': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0061436930': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0061477520': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0062682512': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0064484301': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0064924282': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0065264564': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': True,
#   'Human–computer interaction': False},
#  'carticle_0065978023': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0068724335': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0073533023': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0074532197': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0074813904': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': True},
#  'carticle_0076754421': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0076934775': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0078578119': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0081222999': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0084350413': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': True},
#  'carticle_0084688248': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0084762993': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0085246537': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0085809617': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0086464332': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0086908626': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0088644650': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0090756266': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0091034951': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0091068610': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0091307304': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0092700112': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0093205708': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0097572837': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0097730195': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0098250244': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0104040290': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0107348197': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0108211876': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0108708275': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0110523322': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0112051066': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0117297937': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0117602527': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0117755750': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0121323251': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0121916670': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0122696897': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0128826040': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0128830274': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0129209848': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0129596539': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0132749925': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': True},
#  'carticle_0135492408': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0135695736': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0136472612': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0136553613': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0137072152': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0139611696': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0144371076': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0145403882': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': True},
#  'carticle_0145787309': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0145813560': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0146318375': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0147009937': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': True},
#  'carticle_0154225714': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0154289156': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0154333910': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0157489755': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0157717500': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0163850398': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0164039921': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0165770296': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0171028584': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0172714808': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0173663893': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0173911628': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0176451370': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': True,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0177660956': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': True,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0178706995': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0180451292': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0181562086': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0182868289': {'Algorithms': False,
#   'AI/ML': False,
# ...
#  'carticle_0223151588': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0224145118': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0225137235': {'Algorithms': True,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0227527884': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0228079381': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0228198567': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0230668035': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0231055347': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0234422650': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0236463819': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0242067634': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0243140061': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0243652890': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0246251099': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0248196929': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0249018909': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0249075907': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0250967498': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0257101576': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0257630437': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0258729234': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0259136941': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0261552876': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0262122537': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0263014828': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0264845823': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0265008769': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0267824948': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0271396064': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': True,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0272010185': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0272338864': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0272369659': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0274481222': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': True,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0281313899': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0282096969': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0282214463': {'Algorithms': False,
#   'AI/ML': True,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0282910979': {'Algorithms': True,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': True,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0283260101': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0283441203': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': True,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0284237769': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0284713195': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0285359475': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': True,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0285400320': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': True,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0285436562': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0291961272': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': False,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': False,
#   'Human–computer interaction': False},
#  'carticle_0292188794': {'Algorithms': False,
#   'AI/ML': False,
#   'Computer engineering': True,
#   'Graphics': False,
#   'Networks': False,
#   'Security & Privacy': False,
#   'IR & Knowledge management': False,
#   'Software': False,
#   'Theoretical computer science': False,
#   'High Performace Computing': True,
#   'Human–computer interaction': False}}

# %%
y_pred
# Out:
# {'carticle_0000255204': 'Simulation',
#  'carticle_0000293880': 'Networks',
#  'carticle_0001990826': 'Networks',
#  'carticle_0002436541': 'Software',
#  'carticle_0002565774': 'Theoretical computer science',
#  'carticle_0003044952': 'Simulation',
#  'carticle_0004118963': 'Computational science',
#  'carticle_0004834905': 'Theoretical computer science',
#  'carticle_0006211110': 'AI/ML',
#  'carticle_0007064058': 'AI/ML',
#  'carticle_0009278952': 'Algorithm',
#  'carticle_0009850090': 'Computer engineering',
#  'carticle_0011291905': 'Computer vision',
#  'carticle_0012543572': 'IR & Knowledge management',
#  'carticle_0013350185': 'Networks',
#  'carticle_0013603907': 'Simulation',
#  'carticle_0014121826': 'Simulation',
#  'carticle_0017394439': 'Telecommunications',
#  'carticle_0017641391': 'Networks',
#  'carticle_0018137783': 'High Performace Computing',
#  'carticle_0018187318': 'Theoretical computer science',
#  'carticle_0019307725': 'Algorithm',
#  'carticle_0020037141': 'Computer vision',
#  'carticle_0021247370': 'AI/ML',
#  'carticle_0022843745': 'AI/ML',
#  'carticle_0023217678': 'Human–computer interaction',
#  'carticle_0024107731': 'AI/ML',
#  'carticle_0024168805': 'Telecommunications',
#  'carticle_0024385204': 'Algorithm',
#  'carticle_0024558825': 'Security & Privacy',
#  'carticle_0026094802': 'Computer engineering',
#  'carticle_0028126695': 'Algorithm',
#  'carticle_0028991759': 'Algorithm',
#  'carticle_0029314895': 'Speech recognition',
#  'carticle_0030106975': 'Computer engineering',
#  'carticle_0030404407': 'Telecommunications',
#  'carticle_0031233239': 'Networks',
#  'carticle_0033899195': 'Computer engineering',
#  'carticle_0036075099': 'Theoretical computer science',
#  'carticle_0036618532': 'Telecommunications',
#  'carticle_0036801392': 'Multimedia',
#  'carticle_0041076223': 'Algorithm',
#  'carticle_0043853873': 'Software',
#  'carticle_0046488495': 'Computer vision',
#  'carticle_0047104493': 'High Performace Computing',
#  'carticle_0050796348': 'Computer engineering',
#  'carticle_0051872470': 'IR & Knowledge management',
#  'carticle_0052558902': 'IR & Knowledge management',
#  'carticle_0052682019': 'Software',
#  'carticle_0053700591': 'Algorithm',
#  'carticle_0053742823': 'Networks',
#  'carticle_0055755770': 'Algorithm',
#  'carticle_0055761849': 'Computer graphics (images)',
#  'carticle_0056197364': 'Human–computer interaction',
#  'carticle_0056775235': 'Human–computer interaction',
#  'carticle_0056828099': 'AI/ML',
#  'carticle_0058086075': 'IR & Knowledge management',
#  'carticle_0058952208': 'Software',
#  'carticle_0060114497': 'AI/ML',
#  'carticle_0060565286': 'Theoretical computer science',
#  'carticle_0061436930': 'Computer vision',
#  'carticle_0061477520': 'AI/ML',
#  'carticle_0062682512': 'Security & Privacy',
#  'carticle_0064484301': 'Algorithm',
#  'carticle_0064924282': 'Multimedia',
#  'carticle_0065264564': 'Computer graphics (images)',
#  'carticle_0065978023': 'AI/ML',
#  'carticle_0068724335': 'Simulation',
#  'carticle_0073533023': 'Networks',
#  'carticle_0074532197': 'IR & Knowledge management',
#  'carticle_0074813904': 'IR & Knowledge management',
#  'carticle_0076754421': 'Telecommunications',
#  'carticle_0076934775': 'AI/ML',
#  'carticle_0078578119': 'High Performace Computing',
#  'carticle_0081222999': 'Networks',
#  'carticle_0084350413': 'Simulation',
#  'carticle_0084688248': 'IR & Knowledge management',
#  'carticle_0084762993': 'High Performace Computing',
#  'carticle_0085246537': 'IR & Knowledge management',
#  'carticle_0085809617': 'Algorithm',
#  'carticle_0086464332': 'AI/ML',
#  'carticle_0086908626': 'Computer vision',
#  'carticle_0088644650': 'Computer vision',
#  'carticle_0090756266': 'Software',
#  'carticle_0091034951': 'Networks',
#  'carticle_0091068610': 'Software',
#  'carticle_0091307304': 'Theoretical computer science',
#  'carticle_0092700112': 'Natural language processing',
#  'carticle_0093205708': 'Networks',
#  'carticle_0097572837': 'AI/ML',
#  'carticle_0097730195': 'Software',
#  'carticle_0098250244': 'Theoretical computer science',
#  'carticle_0104040290': 'High Performace Computing',
#  'carticle_0107348197': 'Software',
#  'carticle_0108211876': 'Software',
#  'carticle_0108708275': 'AI/ML',
#  'carticle_0110523322': 'IR & Knowledge management',
#  'carticle_0112051066': 'Simulation',
#  'carticle_0117297937': 'AI/ML',
#  'carticle_0117602527': 'Simulation',
#  'carticle_0117755750': 'Telecommunications',
#  'carticle_0121323251': 'Security & Privacy',
#  'carticle_0121916670': 'Simulation',
#  'carticle_0122696897': 'Software',
#  'carticle_0128826040': 'Security & Privacy',
#  'carticle_0128830274': 'Speech recognition',
#  'carticle_0129209848': 'Telecommunications',
#  'carticle_0129596539': 'AI/ML',
#  'carticle_0132749925': 'Natural language processing',
#  'carticle_0135492408': 'Security & Privacy',
#  'carticle_0135695736': 'AI/ML',
#  'carticle_0136472612': 'IR & Knowledge management',
#  'carticle_0136553613': 'Telecommunications',
#  'carticle_0137072152': 'Telecommunications',
#  'carticle_0139611696': 'AI/ML',
#  'carticle_0144371076': 'Simulation',
#  'carticle_0145403882': 'Theoretical computer science',
#  'carticle_0145787309': 'AI/ML',
#  'carticle_0145813560': 'Theoretical computer science',
#  'carticle_0146318375': 'Computer engineering',
#  'carticle_0147009937': 'Computer engineering',
#  'carticle_0154225714': 'Theoretical computer science',
#  'carticle_0154289156': 'Telecommunications',
#  'carticle_0154333910': 'Security & Privacy',
#  'carticle_0157489755': 'IR & Knowledge management',
#  'carticle_0157717500': 'Software',
#  'carticle_0163850398': 'Software',
#  'carticle_0164039921': 'Simulation',
#  'carticle_0165770296': 'Networks',
#  'carticle_0171028584': 'Software',
#  'carticle_0172714808': 'Software',
#  'carticle_0173663893': 'AI/ML',
#  'carticle_0173911628': 'AI/ML',
#  'carticle_0176451370': 'Software',
#  'carticle_0177660956': 'IR & Knowledge management',
#  'carticle_0178706995': 'Algorithm',
#  'carticle_0180451292': 'Computer engineering',
#  'carticle_0181562086': 'Simulation',
#  'carticle_0182868289': 'IR & Knowledge management',
#  'carticle_0186513312': 'Networks',
#  'carticle_0187359029': 'Computer graphics (images)',
#  'carticle_0188819773': 'Networks',
#  'carticle_0189168626': 'Human–computer interaction',
#  'carticle_0191519227': 'Software',
#  'carticle_0192716124': 'Computer engineering',
#  'carticle_0194356025': 'Human–computer interaction',
#  'carticle_0194393819': 'Software',
#  'carticle_0195941798': 'Simulation',
#  'carticle_0196372887': 'Telecommunications',
#  'carticle_0196673376': 'Human–computer interaction',
#  'carticle_0196841687': 'Computer engineering',
#  'carticle_0197001810': 'Simulation',
#  'carticle_0199048202': 'IR & Knowledge management',
#  'carticle_0199920140': 'Networks',
#  'carticle_0201318698': 'AI/ML',
#  'carticle_0202033185': 'IR & Knowledge management',
#  'carticle_0202289062': 'IR & Knowledge management',
#  'carticle_0203368448': 'AI/ML',
#  'carticle_0204289799': 'Computational science',
#  'carticle_0205964525': 'Software',
#  'carticle_0206083025': 'Simulation',
#  'carticle_0210751618': 'AI/ML',
#  'carticle_0211666030': 'Telecommunications',
#  'carticle_0213441209': 'Human–computer interaction',
#  'carticle_0213869208': 'Computer engineering',
#  'carticle_0213907462': 'Software',
#  'carticle_0214184444': 'Computer vision',
#  'carticle_0214564587': 'AI/ML',
#  'carticle_0216500770': 'Security & Privacy',
#  'carticle_0216710410': 'Simulation',
#  'carticle_0216907772': 'IR & Knowledge management',
#  'carticle_0218154062': 'AI/ML',
#  'carticle_0220932320': 'Simulation',
#  'carticle_0222797071': 'Telecommunications',
#  'carticle_0223151588': 'Software',
#  'carticle_0224145118': 'Networks',
#  'carticle_0225137235': 'Theoretical computer science',
#  'carticle_0227527884': 'IR & Knowledge management',
#  'carticle_0228079381': 'IR & Knowledge management',
#  'carticle_0228198567': 'Simulation',
#  'carticle_0230668035': 'IR & Knowledge management',
#  'carticle_0231055347': 'IR & Knowledge management',
#  'carticle_0234422650': 'Telecommunications',
#  'carticle_0236463819': 'Simulation',
#  'carticle_0242067634': 'Theoretical computer science',
#  'carticle_0243140061': 'Simulation',
#  'carticle_0243652890': 'Speech recognition',
#  'carticle_0246251099': 'AI/ML',
#  'carticle_0248196929': 'Networks',
#  'carticle_0249018909': 'AI/ML',
#  'carticle_0249075907': 'Computer vision',
#  'carticle_0250967498': 'Computer vision',
#  'carticle_0257101576': 'IR & Knowledge management',
#  'carticle_0257630437': 'Algorithm',
#  'carticle_0258729234': 'Telecommunications',
#  'carticle_0259136941': 'Simulation',
#  'carticle_0261552876': 'Security & Privacy',
#  'carticle_0262122537': 'Algorithm',
#  'carticle_0263014828': 'Algorithm',
#  'carticle_0264845823': 'Human–computer interaction',
#  'carticle_0265008769': 'Telecommunications',
#  'carticle_0267824948': 'Telecommunications',
#  'carticle_0271396064': 'Networks',
#  'carticle_0272010185': 'Simulation',
#  'carticle_0272338864': 'Simulation',
#  'carticle_0272369659': 'Telecommunications',
#  'carticle_0274481222': 'Security & Privacy',
#  'carticle_0281313899': 'Simulation',
#  'carticle_0282096969': 'AI/ML',
#  'carticle_0282214463': 'Software',
#  'carticle_0282910979': 'High Performace Computing',
#  'carticle_0283260101': 'Theoretical computer science',
#  'carticle_0283441203': 'Security & Privacy',
#  'carticle_0284237769': 'Simulation',
#  'carticle_0284713195': 'Human–computer interaction',
#  'carticle_0285359475': 'Networks',
#  'carticle_0285400320': 'Simulation',
#  'carticle_0285436562': 'IR & Knowledge management',
#  'carticle_0291961272': 'AI/ML',
#  'carticle_0292188794': 'Software'}

# %%
y_pred = {merged_id: {k: v for k, v in pred.items() if k in labels} for merged_id, pred in y_pred.items()}
# y_pred_array = list({k: v for k, v in pred.items()} for pred in y_pred.values())
# y_pred_array[0]
y_pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_294775/3733692532.py in <module>
# ----> 1 y_pred = {merged_id: {k: v for k, v in pred.items() if k in labels} for merged_id, pred in y_pred.items()}
#       2 # y_pred_array = list({k: v for k, v in pred.items()} for pred in y_pred.values())
#       3 # y_pred_array[0]
#       4 y_pred
#
# /tmp/ipykernel_294775/3733692532.py in <dictcomp>(.0)
# ----> 1 y_pred = {merged_id: {k: v for k, v in pred.items() if k in labels} for merged_id, pred in y_pred.items()}
#       2 # y_pred_array = list({k: v for k, v in pred.items()} for pred in y_pred.values())
#       3 # y_pred_array[0]
#       4 y_pred
#
# AttributeError: 'str' object has no attribute 'items'

# %%
binary_pred = {k: dichotomize(v, top_k=1) for k, v in y_pred.items()}
# binary_pred
# classification_report(to_arrays(y_true), to_arrays(binary_pred))
# y_pred
# to_arrays(binary_pred)
# classification_report(list(y_true.values()), to_arrays(binary_pred))
# len(to_arrays(binary_pred)[0])
# list(y_true.values())

# %%
def top_k_accuracy(true_values, pred_values, top_k=5, proportion=True):
    true_values = list(true_values.values())
    pred_values = list(pred_values.values())
    assert len(true_values) == len(pred_values)
    n = 0
    correct = {i: 0 for i in range(top_k)}
    for true, pred in zip(true_values, pred_values):
        true_fields = {k for k, v in true.items() if v}
        if not len(true_fields):
            # If we've restricted the labels for evalutaion to STEM fields, discard the docs with no positive labels
            continue
        # Ensure that fields are in order of score descending
        pred = [k for k, v in sorted(pred.items(), key=lambda x: x[1], reverse=True)]
        # This is a hack for having annotated multilabel -- if there are 2 true labels, we're taking them
        # interchangeably. We look at the top-scoring label, and check whether it's among the true labels. If so, we
        # count that as accurate @ 1. If not, we check the 2nd-scoring label. If among the true labels, that's accurate
        # @ 2
        for i in range(top_k):
            if pred[i] in true_fields:
                correct[i] += 1
                break
        n += 1
    # The above gave us counts for how often the top-scoring field is correct; if not, how often the 2nd-ranked field
    # label is correct ... and so on to the 5th-ranked field. Taking a cumulative sum over these counts gives us how
    # often a correct label (*the* true label if we manually chose a single label, or one of the correct labels if we
    # chose more than one ... in practice it's mostly 1 label; some 2 labels; rarely 3 labels) is the top label; among
    # the top 2 labels; among the top 3 labels ...
    for i in reversed(range(top_k)):
        for j in range(i):
            correct[i] += correct[j]

    if proportion:
        return {k: x / n for k, x in correct.items()}
    return correct

# %%
top_k_accuracy(y_true, y_pred)
