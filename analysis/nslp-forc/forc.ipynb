# %%
import csv
import json
import re
from collections import defaultdict, Counter

# %%
with open("forc4cl-corpus/val.csv", "r") as csvfile:
    csvreader = csv.DictReader(csvfile)
    score_output = open("to_score_val.jsonl", "w")
    forc_output = open("fields_output_val.jsonl", "w")
    for row in csvreader:
        if not (row["title"] or row["abstract"]):
            continue
        text = f'{row["title"] if row["title"] else ""}. {row["abstract"] if row["abstract"] else ""}'
        pattern = re.compile("([^[:alpha:]\\s\\d])|(\\b\\d+\\b)")
        text = pattern.sub("", text)
        new_pattern = re.compile("[\\r\\n\\v\\t]+")
        text = new_pattern.sub(" ", text).lower().strip()
        score_output.write(json.dumps({"merged_id": row["acl_id"], "text": text}) + "\n")
        forc_output.write(json.dumps({"merged_id": row["acl_id"], "level1": row["Level1"], "level2": row["Level2"], "level3": row["Level3"]}) + "\n")
    score_output.close()
    forc_output.close()

# %%
level_ones = set()
level_twos = set()
level_threes = set()
matchup = {}
reverse_matchup = {}
with open("cset-forc-crosswalk.csv", "r") as csvfile:
    csvreader = csv.DictReader(csvfile)
    for row in csvreader:
        if row["FOS"]:
            initial = {"level one": row["level zero"]}
            if row["level one"]:
                initial["level two"] = row["level one"]
                if row["level two"]:
                    level_threes.add(row["level two"])
                    initial["level three"] = row["level two"]
                    reverse_matchup[row["level two"]] = row["FOS"]
                else:
                    level_twos.add(row["level one"])
                    reverse_matchup[row["level one"]] = row["FOS"]
            else:
                level_ones.add(row["level zero"])
                reverse_matchup[row["level zero"]] = row["FOS"]
            matchup[row["FOS"]] = initial

# %%
considered_fos = set([i.lower() for i in matchup.keys()])

# %%
considered_fos
# Out:
# {'active learning',
#  'adversarial machine learning',
#  'algorithmic bias',
#  'argument mining',
#  'automatic summarization',
#  'chatbots',
#  'cluster analysis',
#  'collaborative filtering',
#  'commonsense reasoning',
#  'data augmentation',
#  'dialogue systems',
#  'distributed search engine',
#  'ethics of artificial intelligence',
#  'generative models',
#  'information extraction',
#  'information retrieval',
#  'knowledge graphs',
#  'knowledge representation and reasoning',
#  'machine translation',
#  'multi-agent systems',
#  'multi-label classification',
#  'multimodal learning',
#  'one-shot learning',
#  'ontology learning',
#  'parsing',
#  'question answering',
#  'recommender systems',
#  'reinforcement learning',
#  'semantic parsing',
#  'sentiment analysis',
#  'speech recognition',
#  'transfer learning',
#  'unsupervised learning'}

# %%
levels = {}
levels_reversed = defaultdict(set)
children = defaultdict(list)
parents = {}
with open("../../assets/fields/all_fields_hierarchy.jsonl", "r") as json_file:
    data = [json.loads(line) for line in json_file]
for row in data:
    levels[row["child_display_name"].lower()] = int(row["child_level"])
    levels_reversed[int(row["child_level"])].add(row["child_display_name"].lower())
    if row["parent_level"] == 0:
        levels[row["display_name"].lower()] = row["parent_level"]
        levels_reversed[row["parent_level"]].add(row["display_name"].lower())
    children[row["display_name"].lower()].append(row["child_display_name"].lower())
    parents[row["child_display_name"].lower().strip()] = row["display_name"].lower().strip()

# %%
i = 0
top_fields = {}
all_top_fields = {}
with open("forc4cl-corpus/en_scores.jsonl", "r") as jsonfile:
    data = [json.loads(line) for line in jsonfile]
    for row in data:
        max_dict = defaultdict(list)
        field_dict = {}
        for field in row["fields"]:
            level = levels[field["id"].lower()]
            if field["id"].lower() in considered_fos:
                max_dict[level].append((field["score"], field["id"]))
        all_fields = []
        for level in max_dict:
            top_five_fields = sorted(max_dict[level], reverse=True)[:1]
            field_dict[level] = [i[1].lower() for i in top_five_fields]
            all_fields.extend([i[1].lower() for i in top_five_fields])
        top_fields[row["merged_id"]] = field_dict
        all_top_fields[row["merged_id"]] = set(all_fields)
        i += 1

# %%
true_positives = 0
false_positives = 0
true_negatives = 0
false_negatives = 0
false_pos_ids = {}
with open("forc4cl-corpus/en_scores.jsonl", "r") as jsonfile:
    data = [json.loads(line) for line in jsonfile]
    for row in data:
        if row["merged_id"] in forc_dict:
            expected = forc_dict[row["merged_id"]]
            expected_filtered = [i for i in expected["level1"] if i in level_ones]
            expected_filtered.extend([i for i in expected["level2"] if i in level_twos])
            expected_filtered.extend([i for i in expected["level3"] if i in level_threes])
            if expected_filtered:
                found = False
                for field in expected_filtered:
                    if reverse_matchup[field].lower() in all_top_fields[row["merged_id"]]:
                        found = True
                    # else:
                        # false_negatives += 1
                if found:
                    true_positives += 1
                else:
                    false_negatives += 1
            else:
                found = False
                for field in all_top_fields[row["merged_id"]]:
                    if field in considered_fos:
                        found = True
                        false_pos_ids[row["merged_id"]] = field
                        # false_positives += 1
                    # else:
                        # true_negatives += 1
                if found:
                    false_positives += 1
                else:
                    true_negatives += 1

# %%
val_json = open("forc4cl-corpus/fields_output_val.jsonl", "r")
forc_data = [json.loads(line) for line in val_json]
test_json = open("forc4cl-corpus/fields_output_test.jsonl", "r")
test_data = [json.loads(line) for line in test_json]
forc_data.extend(test_data)
forc_dict = {}
for row in forc_data:
    level1 = eval(row["level1"])
    if row["level2"]:
        level2 = eval(row["level2"])
    else:
        level2 = []
    if row["level3"]:
        level3 = eval(row["level3"])
    else:
        level3 = []
    forc_dict[row["merged_id"]] = {"level1": level1, "level2": level2, "level3": level3}
val_json.close()
test_json.close()

# %%
true_positives, false_positives, true_negatives, false_negatives
# Out:
# (192, 130, 0, 128)

# %%
true_positives/(true_positives+false_negatives)
# Out:
# 0.6

# %%
all_top_fields
# Out:
# {'L16-1238': {'information extraction', 'speech recognition'},
#  '2020.trac-1.16': {'speech recognition', 'transfer learning'},
#  '2020.parlaclarin-1.7': {'algorithmic bias', 'speech recognition'},
#  '2020.paclic-1.39': {'semantic parsing', 'speech recognition'},
#  'D16-1143': {'collaborative filtering', 'speech recognition'},
#  'S17-1027': {'semantic parsing', 'speech recognition'},
#  '2020.fnp-1.18': {'automatic summarization', 'reinforcement learning'},
#  '2020.splu-1.2': {'information extraction', 'speech recognition'},
#  'O16-2001': {'parsing', 'reinforcement learning'},
#  '2020.emnlp-main.708': {'algorithmic bias', 'reinforcement learning'},
#  '2020.vardial-1.24': {'information extraction', 'speech recognition'},
#  '2016.amta-users.14': {'machine translation', 'speech recognition'},
#  '2020.rail-1.5': {'parsing', 'speech recognition'},
#  'U19-1004': {'generative models', 'speech recognition'},
#  'S17-2168': {'automatic summarization', 'reinforcement learning'},
#  'O17-1013': {'multimodal learning', 'speech recognition'},
#  '2021.ranlp-1.99': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2020.nlpbt-1.2': {'multimodal learning', 'speech recognition'},
#  'D17-1090': {'question answering', 'speech recognition'},
#  '2021.mmsr-1.4': {'multimodal learning', 'speech recognition'},
#  '2021.motra-1.3': {'machine translation', 'speech recognition'},
#  '2022.constraint-1.10': {'information extraction', 'speech recognition'},
#  '2022.deeplo-1.12': {'speech recognition', 'transfer learning'},
#  'K17-3007': {'adversarial machine learning', 'speech recognition'},
#  '2021.findings-acl.296': {'knowledge graphs', 'speech recognition'},
#  '2021.alta-1.11': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2022.gebnlp-1.11': {'algorithmic bias', 'speech recognition'},
#  'D17-1186': {'automatic summarization', 'reinforcement learning'},
#  '2020.sustainlp-1.14': {'information retrieval', 'speech recognition'},
#  '2020.coling-main.485': {'sentiment analysis', 'speech recognition'},
#  '2021.wmt-1.95': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2020.acl-main.713': {'information extraction', 'speech recognition'},
#  '2020.iwltp-1.13': {'information extraction', 'speech recognition'},
#  '2022.dialdoc-1.20': {'collaborative filtering', 'speech recognition'},
#  '2020.trac-1.5': {'reinforcement learning', 'transfer learning'},
#  'L18-1715': {'parsing', 'speech recognition'},
#  'P16-1096': {'semantic parsing', 'speech recognition'},
#  'N19-1209': {'reinforcement learning', 'transfer learning'},
#  '2020.cogalex-1.10': {'knowledge representation and reasoning',
#   'reinforcement learning'},
#  'K19-1074': {'automatic summarization', 'speech recognition'},
#  '2021.triton-1.24': {'machine translation', 'speech recognition'},
#  '2020.rail-1.9': {'collaborative filtering', 'speech recognition'},
#  '2020.figlang-1.25': {'generative models', 'speech recognition'},
#  '2020.globalex-1.1': {'information extraction', 'speech recognition'},
#  '2022.nlppower-1.11': {'algorithmic bias', 'speech recognition'},
#  'W18-0621': {'algorithmic bias', 'reinforcement learning'},
#  '2016.tc-1.7': {'machine translation', 'speech recognition'},
#  '2021.case-1.10': {'automatic summarization', 'speech recognition'},
#  'S19-2211': {'sentiment analysis', 'speech recognition'},
#  'J16-4003': {'semantic parsing', 'speech recognition'},
#  'Y18-1048': {'algorithmic bias', 'speech recognition'},
#  'P19-2059': {'semantic parsing', 'speech recognition'},
#  'W18-4401': {'algorithmic bias', 'speech recognition'},
#  '2020.nlposs-1.3': {'knowledge graphs', 'speech recognition'},
#  '2020.calcs-1.6': {'sentiment analysis', 'speech recognition'},
#  'W18-0616': {'algorithmic bias', 'speech recognition'},
#  '2021.acl-long.239': {'question answering', 'speech recognition'},
#  '2020.alta-1.10': {'sentiment analysis', 'speech recognition'},
#  '2022.nlppower-1.7': {'machine translation', 'speech recognition'},
#  '2021.wat-1.21': {'machine translation', 'speech recognition'},
#  '2020.ccl-1.99': {'sentiment analysis', 'speech recognition'},
#  'P16-1152': {'reinforcement learning', 'transfer learning'},
#  '2021.motra-1.10': {'machine translation', 'speech recognition'},
#  '2021.socialnlp-1.9': {'information extraction', 'speech recognition'},
#  '2020.onion-1.5': {'sentiment analysis', 'speech recognition'},
#  '2021.smm4h-1.22': {'adversarial machine learning', 'speech recognition'},
#  '2021.bionlp-1.5': {'information retrieval', 'reinforcement learning'},
#  '2020.fnp-1.32': {'information extraction', 'speech recognition'},
#  '2021.eacl-main.24': {'chatbots', 'speech recognition'},
#  '2022.naacl-main.32': {'data augmentation', 'reinforcement learning'},
#  '2021.germeval-1.1': {'information extraction', 'speech recognition'},
#  '2020.stoc-1.4': {'algorithmic bias', 'speech recognition'},
#  '2020.cl-2.6': {'parsing', 'speech recognition'},
#  '2020.mwe-1.18': {'knowledge graphs', 'speech recognition'},
#  '2021.eacl-main.311': {'machine translation', 'speech recognition'},
#  '2022.deelio-1.9': {'knowledge graphs', 'speech recognition'},
#  '2021.mmsr-1.9': {'dialogue systems', 'speech recognition'},
#  '2021.naacl-main.64': {'commonsense reasoning', 'reinforcement learning'},
#  '2022.repl4nlp-1.1': {'adversarial machine learning',
#   'reinforcement learning'},
#  '2022.findings-acl.88': {'algorithmic bias', 'speech recognition'},
#  'O16-3002': {'parsing', 'speech recognition'},
#  '2020.sustainlp-1.17': {'information extraction', 'speech recognition'},
#  '2020.sustainlp-1.2': {'information extraction', 'speech recognition'},
#  '2020.paclic-1.40': {'machine translation', 'speech recognition'},
#  '2022.wnu-1.7': {'reinforcement learning', 'transfer learning'},
#  '2021.clpsych-1.20': {'algorithmic bias', 'reinforcement learning'},
#  'W19-8709': {'machine translation', 'speech recognition'},
#  '2020.scai-1.2': {'question answering', 'speech recognition'},
#  '2021.wassa-1.13': {'reinforcement learning', 'sentiment analysis'},
#  '2020.latechclfl-1.11': {'sentiment analysis', 'speech recognition'},
#  '2021.emnlp-main.653': {'algorithmic bias', 'speech recognition'},
#  '2020.isa-1.4': {'algorithmic bias', 'speech recognition'},
#  '2021.blackboxnlp-1.4': {'parsing', 'speech recognition'},
#  '2021.codi-main.13': {'machine translation', 'speech recognition'},
#  '2022.dlg4nlp-1.3': {'knowledge graphs', 'speech recognition'},
#  '2021.acl-long.465': {'question answering', 'speech recognition'},
#  '2021.reinact-1.1': {'semantic parsing', 'speech recognition'},
#  '2021.konvens-1.10': {'information extraction', 'speech recognition'},
#  '2021.konvens-1.24': {'active learning', 'speech recognition'},
#  '2021.wnut-1.24': {'algorithmic bias', 'reinforcement learning'},
#  '2021.case-1.27': {'algorithmic bias', 'speech recognition'},
#  '2021.findings-acl.28': {'information extraction', 'speech recognition'},
#  'K18-2008': {'semantic parsing', 'speech recognition'},
#  '2016.gwc-1.57': {'machine translation', 'speech recognition'},
#  '2020.wnut-1.48': {'sentiment analysis', 'speech recognition'},
#  'Q17-1035': {'generative models', 'speech recognition'},
#  '2020.parlaclarin-1.2': {'information extraction', 'speech recognition'},
#  '2022.repl4nlp-1.18': {'reinforcement learning', 'unsupervised learning'},
#  '2022.lnls-1.5': {'active learning', 'reinforcement learning'},
#  '2020.argmining-1.12': {'argument mining', 'speech recognition'},
#  '2021.bsnlp-1.8': {'machine translation', 'speech recognition'},
#  '2021.calcs-1.2': {'sentiment analysis', 'speech recognition'},
#  '2020.nlpcovid19-acl.4': {'reinforcement learning', 'transfer learning'},
#  '2021.codi-main.1': {'question answering', 'speech recognition'},
#  '2020.lt4gov-1.1': {'information extraction', 'speech recognition'},
#  '2022.clpsych-1.8': {'speech recognition', 'transfer learning'},
#  '2020.clssts-1.7': {'information retrieval', 'speech recognition'},
#  'Q17-1016': {'sentiment analysis', 'speech recognition'},
#  'J17-4003': {'parsing', 'speech recognition'},
#  '2022.naacl-main.261': {'automatic summarization', 'speech recognition'},
#  'W19-5413': {'machine translation', 'speech recognition'},
#  'W17-3528': {'information extraction', 'speech recognition'},
#  '2019.icon-1.20': {'sentiment analysis', 'speech recognition'},
#  '2021.cl-3.22': {'semantic parsing', 'speech recognition'},
#  '2020.emnlp-main.342': {'automatic summarization', 'speech recognition'},
#  '2022.humeval-1.9': {'information extraction', 'speech recognition'},
#  'Q19-1008': {'multimodal learning', 'speech recognition'},
#  'R19-1155': {'information extraction', 'speech recognition'},
#  '2021.wassa-1.3': {'algorithmic bias', 'reinforcement learning'},
#  'W17-4424': {'generative models', 'speech recognition'},
#  'K18-2004': {'parsing', 'speech recognition'},
#  'K17-2012': {'one-shot learning', 'speech recognition'},
#  'N18-3008': {'collaborative filtering', 'speech recognition'},
#  '2020.spnlp-1.10': {'machine translation', 'reinforcement learning'},
#  '2020.codi-1.5': {'dialogue systems', 'speech recognition'},
#  '2021.mmtlrl-1.1': {'machine translation', 'speech recognition'},
#  '2016.gwc-1.32': {'semantic parsing', 'speech recognition'},
#  '2017.mtsummit-commercial.13': {'machine translation', 'speech recognition'},
#  '2021.mtsummit-research.7': {'machine translation', 'speech recognition'},
#  '2021.ltedi-1.8': {'algorithmic bias', 'speech recognition'},
#  '2020.cl-2.7': {'algorithmic bias', 'speech recognition'},
#  '2020.dt4tp-1.3': {'information extraction', 'reinforcement learning'},
#  '2020.tlt-1.7': {'parsing', 'speech recognition'},
#  'W16-3717': {'machine translation', 'speech recognition'},
#  '2021.lchange-1.8': {'semantic parsing', 'speech recognition'},
#  '2020.pam-1.10': {'algorithmic bias', 'speech recognition'},
#  '2020.stoc-1.2': {'multi-agent systems', 'speech recognition'},
#  '2021.cmcl-1.21': {'algorithmic bias', 'speech recognition'},
#  '2020.cogalex-1.3': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2021.sdp-1.12': {'automatic summarization', 'speech recognition'},
#  '2016.tc-1.6': {'algorithmic bias', 'reinforcement learning'},
#  '2020.ldl-1.11': {'speech recognition', 'transfer learning'},
#  'D17-1217': {'sentiment analysis', 'speech recognition'},
#  '2020.msr-1.3': {'data augmentation', 'speech recognition'},
#  'U16-1011': {'reinforcement learning', 'unsupervised learning'},
#  '2021.louhi-1.5': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2020.aacl-srw.23': {'multi-label classification', 'reinforcement learning'},
#  '2021.gebnlp-1.11': {'algorithmic bias', 'speech recognition'},
#  '2022.naacl-industry.22': {'machine translation', 'speech recognition'},
#  'P18-1119': {'automatic summarization', 'speech recognition'},
#  'L16-1706': {'machine translation', 'speech recognition'},
#  '2020.aespen-1.1': {'information extraction', 'speech recognition'},
#  '2020.iwdp-1.2': {'machine translation', 'speech recognition'},
#  '2020.conll-1.19': {'machine translation', 'speech recognition'},
#  '2022.eamt-1.30': {'machine translation', 'speech recognition'},
#  'S18-2008': {'semantic parsing', 'speech recognition'},
#  '2021.sdp-1.2': {'information retrieval', 'speech recognition'},
#  '2021.quasy-1.2': {'parsing', 'speech recognition'},
#  '2021.metanlp-1.4': {'reinforcement learning', 'transfer learning'},
#  '2022.unimplicit-1.4': {'automatic summarization', 'speech recognition'},
#  '2020.framenet-1.7': {'machine translation', 'speech recognition'},
#  '2021.nlpmc-1.1': {'dialogue systems', 'speech recognition'},
#  '2021.nlp4musa-1.7': {'sentiment analysis', 'speech recognition'},
#  '2021.sigdial-1.37': {'dialogue systems', 'reinforcement learning'},
#  '2021.maiworkshop-1.5': {'multimodal learning', 'speech recognition'},
#  '2021.germeval-1.13': {'data augmentation', 'speech recognition'},
#  '2020.trac-1.15': {'machine translation', 'speech recognition'},
#  '2022.dadc-1.5': {'adversarial machine learning', 'speech recognition'},
#  'C16-1300': {'machine translation', 'speech recognition'},
#  'Q19-1011': {'automatic summarization', 'speech recognition'},
#  '2020.gamnlp-1.12': {'algorithmic bias', 'reinforcement learning'},
#  '2022.nlppower-1.6': {'machine translation', 'speech recognition'},
#  '2022.slpat-1.8': {'algorithmic bias', 'speech recognition'},
#  'Y17-1051': {'machine translation', 'speech recognition'},
#  'N16-1154': {'question answering', 'speech recognition'},
#  'N16-1132': {'machine translation', 'speech recognition'},
#  '2021.bppf-1.3': {'algorithmic bias', 'reinforcement learning'},
#  'W18-6021': {'parsing', 'reinforcement learning'},
#  '2020.pam-1.15': {'algorithmic bias', 'speech recognition'},
#  '2022.semeval-1.230': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2022.sigmorphon-1.21': {'algorithmic bias', 'speech recognition'},
#  '2021.bucc-1.5': {'knowledge graphs', 'speech recognition'},
#  '2020.findings-emnlp.92': {'information extraction', 'speech recognition'},
#  'W16-4110': {'reinforcement learning', 'sentiment analysis'},
#  '2021.findings-acl.75': {'machine translation', 'speech recognition'},
#  '2020.cogalex-1.5': {'semantic parsing', 'speech recognition'},
#  'Q16-1032': {'semantic parsing', 'speech recognition'},
#  '2020.sigdial-1.5': {'ethics of artificial intelligence',
#   'speech recognition'},
#  'K18-1016': {'chatbots', 'speech recognition'},
#  'J19-1003': {'parsing', 'speech recognition'},
#  'W19-0606': {'semantic parsing', 'speech recognition'},
#  '2021.motra-1.5': {'machine translation', 'speech recognition'},
#  '2020.readi-1.12': {'sentiment analysis', 'speech recognition'},
#  '2020.bea-1.18': {'parsing', 'speech recognition'},
#  '2021.nlp4posimpact-1.11': {'information extraction', 'speech recognition'},
#  '2022.constraint-1.1': {'knowledge graphs', 'speech recognition'},
#  '2020.nlpmc-1.3': {'chatbots', 'speech recognition'},
#  'J18-2003': {'parsing', 'reinforcement learning'},
#  '2020.dmr-1.7': {'reinforcement learning', 'semantic parsing'},
#  '2020.lrec-1.450': {'reinforcement learning', 'transfer learning'},
#  '2022.nlp4convai-1.16': {'ontology learning', 'speech recognition'},
#  'Q17-1014': {'algorithmic bias', 'speech recognition'},
#  'W19-1006': {'knowledge representation and reasoning',
#   'reinforcement learning'},
#  'C18-1275': {'reinforcement learning', 'semantic parsing'},
#  '2020.ngt-1.28': {'machine translation', 'speech recognition'},
#  '2022.ltedi-1.3': {'machine translation', 'speech recognition'},
#  '2022.insights-1.14': {'question answering', 'speech recognition'},
#  '2022.tacl-1.6': {'multi-label classification', 'reinforcement learning'},
#  '2020.crac-1.12': {'active learning', 'reinforcement learning'},
#  '2020.bea-1.11': {'automatic summarization', 'speech recognition'},
#  '2020.codi-1.9': {'parsing', 'speech recognition'},
#  '2021.semeval-1.157': {'reinforcement learning', 'transfer learning'},
#  'P18-2108': {'information extraction', 'speech recognition'},
#  '2020.ldl-1.5': {'algorithmic bias', 'reinforcement learning'},
#  'D19-1264': {'knowledge graphs', 'reinforcement learning'},
#  'C16-1138': {'data augmentation', 'speech recognition'},
#  '2021.vardial-1.16': {'multimodal learning', 'speech recognition'},
#  '2020.rocling-1.18': {'algorithmic bias', 'reinforcement learning'},
#  '2020.privatenlp-1.5': {'adversarial machine learning', 'speech recognition'},
#  '2021.mmsr-1.5': {'multimodal learning', 'speech recognition'},
#  '2021.mrl-1.9': {'machine translation', 'speech recognition'},
#  '2021.maiworkshop-1.7': {'multimodal learning', 'reinforcement learning'},
#  '2021.metanlp-1.7': {'algorithmic bias', 'speech recognition'},
#  'S16-1172': {'question answering', 'reinforcement learning'},
#  'L18-1722': {'algorithmic bias', 'reinforcement learning'},
#  '2022.bionlp-1.16': {'reinforcement learning', 'unsupervised learning'},
#  '2022.findings-acl.100': {'adversarial machine learning',
#   'speech recognition'},
#  '2020.peoples-1.2': {'algorithmic bias', 'speech recognition'},
#  '2020.vlsp-1.12': {'parsing', 'speech recognition'},
#  'W16-2213': {'machine translation', 'speech recognition'},
#  'R19-1038': {'automatic summarization', 'speech recognition'},
#  'P17-1063': {'algorithmic bias', 'speech recognition'},
#  '2020.nl4xai-1.13': {'reinforcement learning', 'transfer learning'},
#  '2021.nlp4convai-1.2': {'multi-label classification', 'speech recognition'},
#  '2021.nlp4if-1.18': {'sentiment analysis', 'speech recognition'},
#  '2020.cmlc-1.4': {'information extraction', 'speech recognition'},
#  '2022.slpat-1.2': {'collaborative filtering', 'speech recognition'},
#  '2020.trac-1.23': {'algorithmic bias', 'speech recognition'},
#  '2022.dadc-1.2': {'algorithmic bias', 'speech recognition'},
#  '2021.acl-long.365': {'knowledge graphs', 'reinforcement learning'},
#  '2020.vardial-1.6': {'machine translation', 'speech recognition'},
#  '2019.icon-1.21': {'parsing', 'speech recognition'},
#  'Y18-1082': {'algorithmic bias', 'speech recognition'},
#  '2021.codi-main.15': {'semantic parsing', 'speech recognition'},
#  'Q16-1034': {'machine translation', 'speech recognition'},
#  '2021.disrpt-1.4': {'sentiment analysis', 'speech recognition'},
#  '2017.mtsummit-papers.3': {'machine translation', 'speech recognition'},
#  '2020.aacl-main.90': {'question answering', 'speech recognition'},
#  '2020.challengehml-1.4': {'multimodal learning', 'speech recognition'},
#  '2018.iwslt-1.2': {'automatic summarization', 'speech recognition'},
#  '2020.peoples-1.4': {'sentiment analysis', 'speech recognition'},
#  '2020.nuse-1.4': {'sentiment analysis', 'speech recognition'},
#  '2020.mmw-1.4': {'sentiment analysis', 'speech recognition'},
#  'R19-1075': {'semantic parsing', 'speech recognition'},
#  'N19-1145': {'knowledge representation and reasoning', 'speech recognition'},
#  '2020.lt4hala-1.15': {'machine translation', 'speech recognition'},
#  '2021.sigdial-1.31': {'dialogue systems', 'reinforcement learning'},
#  '2020.sigdial-1.26': {'dialogue systems', 'speech recognition'},
#  '2020.argmining-1.13': {'argument mining', 'speech recognition'},
#  '2022.gebnlp-1.20': {'algorithmic bias', 'speech recognition'},
#  '2022.dadc-1.4': {'adversarial machine learning', 'speech recognition'},
#  '2022.findings-acl.6': {'machine translation', 'speech recognition'},
#  'D18-1020': {'generative models', 'speech recognition'},
#  'Y16-2010': {'machine translation', 'speech recognition'},
#  '2020.wildre-1.10': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2022.cmcl-1.14': {'sentiment analysis', 'speech recognition'},
#  'N19-1129': {'information extraction', 'reinforcement learning'},
#  '2021.disrpt-1.2': {'sentiment analysis', 'speech recognition'},
#  'S19-2199': {'question answering', 'speech recognition'},
#  '2022.trustnlp-1.2': {'ethics of artificial intelligence',
#   'reinforcement learning'},
#  '2021.americasnlp-1.23': {'machine translation', 'speech recognition'},
#  'S19-2198': {'question answering', 'speech recognition'},
#  '2020.textgraphs-1.1': {'knowledge graphs', 'speech recognition'},
#  'W17-5543': {'sentiment analysis', 'speech recognition'},
#  '2020.eval4nlp-1.6': {'automatic summarization', 'speech recognition'},
#  '2020.lrec-1.274': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2021.emnlp-main.289': {'information retrieval', 'speech recognition'},
#  '2021.calcs-1.15': {'information extraction', 'speech recognition'},
#  'Q18-1018': {'question answering', 'reinforcement learning'},
#  '2021.humeval-1.13': {'machine translation', 'reinforcement learning'},
#  '2020.lrec-1.124': {'cluster analysis', 'speech recognition'},
#  '2020.tacl-1.6': {'semantic parsing', 'speech recognition'},
#  'W17-6302': {'parsing', 'speech recognition'},
#  '2020.peoples-1.10': {'sentiment analysis', 'speech recognition'},
#  '2021.iwcs-1.22': {'information extraction', 'reinforcement learning'},
#  '2020.nlposs-1.6': {'information retrieval', 'speech recognition'},
#  '2020.mwe-1.20': {'sentiment analysis', 'speech recognition'},
#  '2021.cinlp-1.8': {'algorithmic bias', 'speech recognition'},
#  '2021.bucc-1.6': {'automatic summarization', 'speech recognition'},
#  '2020.repl4nlp-1.11': {'data augmentation', 'speech recognition'},
#  '2021.acl-long.559': {'parsing', 'speech recognition'},
#  '2020.ccl-1.78': {'data augmentation', 'speech recognition'},
#  '2021.case-1.1': {'information extraction', 'speech recognition'},
#  'J18-2001': {'parsing', 'speech recognition'},
#  '2020.nlpmc-1.1': {'question answering', 'speech recognition'},
#  '2021.eval4nlp-1.2': {'multi-label classification', 'speech recognition'},
#  'L16-1603': {'semantic parsing', 'speech recognition'},
#  '2020.intexsempar-1.4': {'semantic parsing', 'speech recognition'},
#  '2021.cinlp-1.5': {'reinforcement learning', 'sentiment analysis'},
#  'S18-1049': {'sentiment analysis', 'speech recognition'},
#  'N18-1125': {'machine translation', 'speech recognition'},
#  'P16-1033': {'active learning', 'reinforcement learning'},
#  '2020.iwpt-1.24': {'parsing', 'speech recognition'},
#  '2021.cmcl-1.6': {'parsing', 'speech recognition'},
#  'W19-1412': {'speech recognition', 'transfer learning'},
#  '2022.hcinlp-1.3': {'ethics of artificial intelligence',
#   'speech recognition'},
#  '2022.computel-1.6': {'machine translation', 'speech recognition'},
#  '2021.cmcl-1.17': {'active learning', 'speech recognition'},
#  '2021.emnlp-main.103': {'information extraction', 'reinforcement learning'},
#  '2020.readi-1.6': {'sentiment analysis', 'speech recognition'},
#  'W16-2522': {'knowledge representation and reasoning', 'speech recognition'},
#  '2020.scil-1.43': {'semantic parsing', 'speech recognition'},
#  '2020.emnlp-main.712': {'commonsense reasoning', 'speech recognition'},
#  '2022.sigmorphon-1.7': {'speech recognition', 'transfer learning'},
#  '2021.wat-1.2': {'machine translation', 'speech recognition'},
#  'Y17-1018': {'machine translation', 'speech recognition'},
#  '2019.rocling-1.10': {'chatbots', 'speech recognition'},
#  '2021.argmining-1.21': {'speech recognition', 'unsupervised learning'},
#  'K17-3016': {'parsing', 'speech recognition'},
#  '2020.alta-1.8': {'algorithmic bias', 'speech recognition'},
#  '2020.globalex-1.18': {'machine translation', 'speech recognition'},
#  '2020.globalex-1.5': {'knowledge graphs', 'speech recognition'},
#  '2020.parlaclarin-1.4': {'information extraction', 'speech recognition'},
#  '2020.semeval-1.182': {'sentiment analysis', 'speech recognition'},
#  '2021.mtsummit-at4ssl.11': {'machine translation', 'speech recognition'},
#  'U16-1021': {'information extraction', 'speech recognition'},
#  '2022.semeval-1.177': {'question answering', 'speech recognition'},
#  'R19-2008': {'knowledge graphs', 'speech recognition'},
#  '2021.wat-1.16': {'machine translation', 'speech recognition'},
#  '2022.naacl-demo.4': {'information extraction', 'speech recognition'},
#  '2021.smm4h-1.1': {'reinforcement learning', 'sentiment analysis'},
#  'E17-1102': {'machine translation', 'speech recognition'},
#  'W18-0703': {'question answering', 'reinforcement learning'},
#  '2021.mrqa-1.3': {'question answering', 'speech recognition'},
#  '2022.ecnlp-1.13': {'question answering', 'speech recognition'},
#  'E17-1097': {'reinforcement learning', 'unsupervised learning'},
#  '2021.woah-1.6': {'machine translation', 'speech recognition'},
#  '2022.autosimtrans-1.5': {'machine translation', 'speech recognition'},
#  '2020.framenet-1.12': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2020.eamt-1.28': {'machine translation', 'speech recognition'},
#  '2021.reinact-1.3': {'reinforcement learning', 'transfer learning'},
#  '2020.readi-1.5': {'automatic summarization', 'speech recognition'},
#  '2021.ranlp-1.140': {'algorithmic bias', 'speech recognition'},
#  'Q16-1006': {'machine translation', 'speech recognition'},
#  '2021.blackboxnlp-1.36': {'adversarial machine learning',
#   'reinforcement learning'},
#  '2021.nodalida-main.5': {'machine translation', 'speech recognition'},
#  '2020.deelio-1.10': {'commonsense reasoning', 'speech recognition'},
#  '2022.autosimtrans-1.2': {'machine translation', 'speech recognition'},
#  '2020.mwe-1.8': {'sentiment analysis', 'speech recognition'},
#  '2020.lt4gov-1.5': {'machine translation', 'speech recognition'},
#  '2020.inlg-1.27': {'generative models', 'speech recognition'},
#  '2021.findings-acl.428': {'generative models', 'speech recognition'},
#  'P17-2005': {'automatic summarization', 'reinforcement learning'},
#  '2020.iwpt-1.5': {'parsing', 'speech recognition'},
#  'S16-1093': {'reinforcement learning', 'semantic parsing'},
#  '2021.internlp-1.5': {'information retrieval', 'reinforcement learning'},
#  'P19-1181': {'multi-agent systems', 'reinforcement learning'},
#  '2021.naacl-srw.5': {'knowledge representation and reasoning',
#   'speech recognition'},
#  '2020.blackboxnlp-1.15': {'sentiment analysis', 'speech recognition'},
#  'O16-1027': {'sentiment analysis', 'speech recognition'},
#  '2022.fl4nlp-1.3': {'algorithmic bias', 'speech recognition'},
#  '2021.paclic-1.25': {'machine translation', 'speech recognition'},
#  'U18-1004': {'reinforcement learning', 'unsupervised learning'},
#  'Y16-3018': {'algorithmic bias', 'speech recognition'},
#  'N16-1083': {'automatic summarization', 'speech recognition'},
#  '2020.semeval-1.38': {'semantic parsing', 'speech recognition'},
#  'K19-1046': {'reinforcement learning', 'unsupervised learning'},
#  '2021.triton-1.13': {'machine translation', 'speech recognition'},
#  '2021.paclic-1.47': {'adversarial machine learning', 'speech recognition'},
#  'L18-1497': {'knowledge representation and reasoning', 'speech recognition'},
#  'W17-5019': {'algorithmic bias', 'reinforcement learning'},
#  '2020.nlpcovid19-acl.17': {'speech recognition', 'transfer learning'},
#  'U17-1011': {'reinforcement learning', 'transfer learning'},
#  '2020.nlp4call-1.3': {'dialogue systems', 'speech recognition'},
#  '2020.wosp-1.5': {'information retrieval', 'speech recognition'},
#  '2020.smm4h-1.1': {'information extraction', 'reinforcement learning'},
#  '2021.scil-1.56': {'semantic parsing', 'speech recognition'},
#  '2021.clpsych-1.1': {'collaborative filtering', 'speech recognition'},
#  'U19-1022': {'multimodal learning', 'speech recognition'},
#  'C18-1034': {'parsing', 'speech recognition'},
#  '2021.tacl-1.8': {'parsing', 'speech recognition'},
#  '2020.computerm-1.10': {'ontology learning', 'speech recognition'},
#  '2020.sdp-1.7': {'knowledge graphs', 'speech recognition'},
#  'J16-4011': {'information extraction', 'speech recognition'},
#  '2020.globalex-1.2': {'semantic parsing', 'speech recognition'},
#  'W17-2348': {'information retrieval', 'speech recognition'},
#  '2020.msr-1.5': {'parsing', 'speech recognition'},
#  '2022.lchange-1.9': {'information extraction', 'speech recognition'},
#  '2022.wordplay-1.4': {'question answering', 'reinforcement learning'},
#  'Y16-1002': {'information extraction', 'reinforcement learning'},
#  '2020.wnut-1.76': {'speech recognition', 'transfer learning'},
#  '2021.depling-1.10': {'parsing', 'speech recognition'},
#  '2021.isa-1.6': {'information extraction', 'speech recognition'},
#  'K19-1087': {'adversarial machine learning', 'reinforcement learning'},
#  'L16-1341': {'one-shot learning', 'speech recognition'},
#  '2020.readi-1.14': {'information extraction', 'speech recognition'},
#  'Q16-1023': {'parsing', 'speech recognition'},
#  'K19-1069': {'one-shot learning', 'reinforcement learning'},
#  '2020.nlpbt-1.4': {'information extraction', 'speech recognition'},
#  '2021.unimplicit-1.1': {'algorithmic bias', 'speech recognition'},
#  'L16-1561': {'machine translation', 'speech recognition'},
#  '2022.findings-acl.291': {'semantic parsing', 'speech recognition'},
#  '2022.repl4nlp-1.16': {'adversarial machine learning', 'speech recognition'},
#  'L18-1164': {'speech recognition', 'unsupervised learning'},
#  '2021.acl-long.223': {'adversarial machine learning',
#   'reinforcement learning'},
#  '2021.iwpt-1.11': {'cluster analysis', 'reinforcement learning'},
#  '2022.acl-long.381': {'parsing', 'speech recognition'},
#  'C18-1169': {'information extraction', 'speech recognition'},
#  '2021.wanlp-1.51': {'sentiment analysis', 'speech recognition'},
#  '2020.crac-1.10': {'reinforcement learning', 'transfer learning'},
#  '2019.nsurl-1.8': {'question answering', 'speech recognition'},
#  '2021.woah-1.1': {'data augmentation', 'speech recognition'},
#  '2021.louhi-1.8': {'speech recognition', 'unsupervised learning'},
#  '2020.eval4nlp-1.10': {'information extraction', 'speech recognition'},
#  'U16-1005': {'algorithmic bias', 'reinforcement learning'},
#  'U16-1014': {'reinforcement learning', 'unsupervised learning'},
#  '2021.icnlsp-1.8': {'reinforcement learning', 'unsupervised learning'},
#  '2021.ltedi-1.1': {'algorithmic bias', 'speech recognition'},
#  '2016.lilt-13.1': {'parsing', 'speech recognition'},
#  'L16-1033': {'parsing', 'speech recognition'},
#  '2021.fnp-1.9': {'automatic summarization', 'reinforcement learning'},
#  '2021.depling-1.11': {'parsing', 'speech recognition'},
#  'Y16-2019': {'speech recognition', 'unsupervised learning'},
#  'P17-1038': {'active learning', 'speech recognition'},
#  'S17-2105': {'sentiment analysis', 'speech recognition'},
#  '2022.wnu-1.5': {'information extraction', 'reinforcement learning'},
#  'P17-1108': {'automatic summarization', 'speech recognition'},
#  'S16-1164': {'automatic summarization', 'speech recognition'},
#  '2020.alvr-1.5': {'multimodal learning', 'reinforcement learning'},
#  'Y18-1053': {'knowledge representation and reasoning', 'speech recognition'},
#  '2020.onion-1.2': {'machine translation', 'speech recognition'},
#  '2020.semeval-1.299': {'multimodal learning', 'speech recognition'},
#  '2020.evalnlgeval-1.2': {'algorithmic bias', 'speech recognition'},
#  'Q17-1004': {'parsing', 'speech recognition'},
#  '2020.ccl-1.106': {'sentiment analysis', 'speech recognition'},
#  '2021.privatenlp-1.4': {'algorithmic bias', 'speech recognition'},
#  '2021.gem-1.7': {'automatic summarization', 'speech recognition'},
#  '2021.wat-1.6': {'machine translation', 'speech recognition'},
#  '2021.iwclul-1.6': {'parsing', 'reinforcement learning'},
#  '2021.eacl-demos.28': {'active learning', 'reinforcement learning'}}
